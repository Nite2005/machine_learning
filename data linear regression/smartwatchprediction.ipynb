# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#get the training data
dfx= pd.read_csv('C:/Users/ACER/OneDrive/Python/data linear regression/ass/Linear_X_Train.csv')
dfy= pd.read_csv('C:/Users/ACER/OneDrive/Python/data linear regression/ass/Linear_Y_Train.csv')
dfx=dfx.values
dfy= dfy.values
x=dfx.reshape((-1,))
y=dfx.reshape((-1,))
print(x.shape,y.shape)
print(x)
print(y.shape)
# Out:
# (3750,) (3750,)
# [-0.28930742 -0.58880963  1.02750749 ... -0.30516366  1.67583291
#  -0.49175724]
# (3750,)

# %% [markdown]
# Data processing and visualisation

# %%
plt.scatter(x,y)
plt.show()

# %%
x=(x-x.mean())/x.std()
y=y
plt.scatter(x,y)

# %% [markdown]
# Gradient Descent Algorithm

# %%
def hypothesis(x,theta):
    return theta[0]+theta[1]*x

# %%
def error(x,y,theta):
    error=0.0
    for i in range(x.shape[0]):
        hx=hypothesis(x[i],theta)
        error+=(hx-y[i])**2
    return error

# %%
def gradient(x,y,theta):
    grad=np.zeros((2,))
    
    for i in range(x.shape[0]):
        hx=hypothesis(x[i],theta)
        grad[0]+=(hx-y[i])
        grad[1]+=(hx-y[i])*x[i]
    return grad/x.shape[0]

# %%
def gradientDescent(x,y,learning_rate=0.01):
    theta=np.array([-2,0,0.0])
    max_iteration=3000
    itr=0
    error_list=[]
    theta_list=[]
    while(itr<=max_iteration):
        grad=gradient(x,y,theta)
        err=error(x,y,theta)
        error_list.append(err)
        theta_list.append(err)
        theta[0]-=learning_rate*grad[0]
        theta[1]-=learning_rate*grad[1]
        itr+=1
    return theta,error_list,theta_list

# %%
final_theta,error_list,theta_list=gradientDescent(x,y)

# %%
plt.plot(error_list)
plt.show()

# %%
print(final_theta)
# Out:
# [-0.03779466  0.99208013  0.        ]

# %%
#plot the line for testing data
xtest=pd.read_csv('C:/Users/ACER/OneDrive/Python/data linear regression/ass/testingdata/Linear_X_Test.csv')
xtest=xtest.values
x=xtest.reshape((-1,))
print(xtest)
print(x.shape)
# Out:
# [[-1.87794441]
#  [-0.86903192]
#  [-2.53018242]
#  ...
#  [ 0.12800782]
#  [-0.27803759]
#  [-0.68042543]]
# (1250,)

# %%
plt.scatter(x,y,label='Training Data')
plt.plot(xtest,hypothesis(xtest,final_theta),color='orange',label='prediction')
plt.legend()
plt.show()
